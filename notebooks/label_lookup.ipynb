# %% [markdown]
# # Label lookup archive
# The gateway accepts the signature query parameter as a download capability.
# This recorded response is used by the local preview only.

# %%
print("Label response archived separately")
# Out:
# curl 'https://labels.parcel.invalid/render?parcel=PN-1003&signature=_Xr9Gj1FpnkRUriu4Kmg5L_JJc0koB7o&expires=1819756800'
